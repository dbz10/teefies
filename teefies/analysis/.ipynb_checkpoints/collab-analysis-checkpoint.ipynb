# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.summarization import keywords, summarize
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn import utils
import csv
import multiprocessing
import nltk
from nltk.corpus import stopwords
from tqdm import tqdm
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

product_info = pd.read_csv('../data/CatfoodProductInfo.csv')
reviews = pd.read_csv('../data/CatfoodReviewsInfo.csv')
df = reviews.join(product_info.set_index('product'), on='product',how='left')

# %%
df = df.dropna(axis=0,how='any')
brandnames = set(df['brand'].unique())

# %%
df.head(5)
# Out:
#                                              product  review_author  rating  \
# 0  Fancy Feast Grilled Seafood Feast Variety Pack...          Rosie       5
# 1  Fancy Feast Grilled Seafood Feast Variety Pack...      VETTEGIRL       5
# 2  Fancy Feast Grilled Seafood Feast Variety Pack...  Lovethebabies       5
# 3  Fancy Feast Grilled Seafood Feast Variety Pack...           Suzi       5
# 4  Fancy Feast Grilled Seafood Feast Variety Pack...          Nicki       5
#
#                                          review_text  helpful_rank  \
# 0  I try and make this last an entire month as my...             1
# 1  HE LIKES VARIETY EVERY DAY, SO WE ROTATE FROM ...             2
# 2  My two cats are trying the grilled seafood Fan...             2
# 3  I have a 1 year old cat I got from the Humane ...             2
# 4  The last shipment is exactly right.  Minou doe...             0
#
#          brand   price  oz_per_can  num_cans  price_per_oz
# 0  Fancy Feast  $14.79         3.0      24.0      0.205417
# 1  Fancy Feast  $14.79         3.0      24.0      0.205417
# 2  Fancy Feast  $14.79         3.0      24.0      0.205417
# 3  Fancy Feast  $14.79         3.0      24.0      0.205417
# 4  Fancy Feast  $14.79         3.0      24.0      0.205417

# %%
# standardize text
def standardize_text(df, text_field):
    df[text_field] = df[text_field].str.replace(r"http\S+", "")
    df[text_field] = df[text_field].str.replace(r"http", "")
    df[text_field] = df[text_field].str.replace(r"@\S+", "")
    df[text_field] = df[text_field].str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    df[text_field] = df[text_field].str.replace(r"@", "at")
    df[text_field] = df[text_field].str.lower()
    for brandname in brandnames:
        df[text_field] = df[text_field].str.replace(brandname.lower(),"")
        
    # keywordize into tokens
    try:
        kw = keywords(df[text_field].values[0],ratio=0.5,split=True)
        df[text_field] = kw
    except:
        df[text_field] = np.NaN
        
        
    return df

train_documents = []

test_documents = []
i = 0

# Label encode the names
le = preprocessing.LabelEncoder()
df['product_label']=le.fit_transform(df['product'])

# print(train_documents[0])

df_clean = standardize_text(df,'review_text')

# %%
df_clean
# Out:
#                                                  product        review_author  \
# 0      Fancy Feast Grilled Seafood Feast Variety Pack...                Rosie
# 1      Fancy Feast Grilled Seafood Feast Variety Pack...            VETTEGIRL
# 2      Fancy Feast Grilled Seafood Feast Variety Pack...        Lovethebabies
# 3      Fancy Feast Grilled Seafood Feast Variety Pack...                 Suzi
# 4      Fancy Feast Grilled Seafood Feast Variety Pack...                Nicki
# 5      Fancy Feast Grilled Seafood Feast Variety Pack...               Eileen
# 6      Fancy Feast Grilled Seafood Feast Variety Pack...                Vicki
# 7      Fancy Feast Grilled Seafood Feast Variety Pack...                 Josy
# 8      Fancy Feast Grilled Seafood Feast Variety Pack...      JeebaTheChin215
# 9      Fancy Feast Grilled Seafood Feast Variety Pack...            Hollybaby
# 10     Fancy Feast Grilled Seafood Feast Variety Pack...               Baggie
# 11     Fancy Feast Grilled Seafood Feast Variety Pack...                 Malv
# 12     Fancy Feast Grilled Seafood Feast Variety Pack...           Iguanamama
# 13     Fancy Feast Grilled Seafood Feast Variety Pack...                Kitty
# 14     Fancy Feast Grilled Seafood Feast Variety Pack...               woocie
# 15     Fancy Feast Grilled Seafood Feast Variety Pack...                 Dani
# 16     Fancy Feast Grilled Seafood Feast Variety Pack...                Katie
# 17     Fancy Feast Grilled Seafood Feast Variety Pack...            lilylover
# 18     Fancy Feast Grilled Seafood Feast Variety Pack...             Jilesoph
# 19     Fancy Feast Grilled Seafood Feast Variety Pack...                 JOAN
# 20     Fancy Feast Grilled Seafood Feast Variety Pack...          KittyMohawk
# 21     Fancy Feast Grilled Seafood Feast Variety Pack...           Smellsgood
# 22     Fancy Feast Grilled Seafood Feast Variety Pack...                DrSuz
# 23     Fancy Feast Grilled Seafood Feast Variety Pack...                bkvav
# 24     Fancy Feast Grilled Seafood Feast Variety Pack...           CeeCeesMom
# 25     Fancy Feast Grilled Seafood Feast Variety Pack...                Ruthy
# 26     Fancy Feast Grilled Seafood Feast Variety Pack...                Lizzy
# 27     Fancy Feast Grilled Seafood Feast Variety Pack...              Sandy68
# 28     Fancy Feast Grilled Seafood Feast Variety Pack...               ariane
# 29     Fancy Feast Grilled Seafood Feast Variety Pack...                Angel
# ...                                                  ...                  ...
# 38529  Nutro Max Adult Chicken Supreme Entree Chunks ...                 NorC
# 38530  Nutro Max Adult Chicken Supreme Entree Chunks ...           Oregonthea
# 38531  Nutro Max Adult Chicken Supreme Entree Chunks ...               Joanne
# 38532  Nutro Max Adult Chicken Supreme Entree Chunks ...              Barbara
# 38533  Nutro Max Adult Chicken Supreme Entree Chunks ...                Lb924
# 38534  Nutro Max Adult Chicken Supreme Entree Chunks ...          justtinac46
# 38535  Nutro Max Adult Chicken Supreme Entree Chunks ...                 JimP
# 38536  Nutro Max Adult Chicken Supreme Entree Chunks ...                Mango
# 38537  Nutro Max Adult Chicken Supreme Entree Chunks ...               WCCats
# 38538  Nutro Max Adult Chicken Supreme Entree Chunks ...             Patabami
# 38539  Nutro Max Adult Chicken Supreme Entree Chunks ...           BeemersMom
# 38540  Nutro Max Adult Chicken Supreme Entree Chunks ...                 Eric
# 38541  Nutro Max Adult Chicken Supreme Entree Chunks ...  WiseMiddleAgedMan78
# 38542  Nutro Max Adult Chicken Supreme Entree Chunks ...                LAYNA
# 38543  Nutro Max Adult Chicken Supreme Entree Chunks ...               Nikkij
# 38544  Nutro Max Adult Chicken Supreme Entree Chunks ...          Guacamolito
# 38545  Nutro Max Adult Chicken Supreme Entree Chunks ...              Alberta
# 38546  Nutro Max Adult Chicken Supreme Entree Chunks ...            Constanza
# 38547  Nutro Max Adult Chicken Supreme Entree Chunks ...                 bolo
# 38548  Nutro Max Adult Chicken Supreme Entree Chunks ...               Joanie
# 38549  Nutro Max Adult Chicken Supreme Entree Chunks ...            Enginecat
# 38550  Nutro Max Adult Chicken Supreme Entree Chunks ...              GBankel
# 38551  Nutro Max Adult Chicken Supreme Entree Chunks ...        n2fitness1994
# 38552  Nutro Max Adult Chicken Supreme Entree Chunks ...                Jerry
# 38553  Nutro Max Adult Chicken Supreme Entree Chunks ...           LuvsCheese
# 38554  Nutro Max Adult Chicken Supreme Entree Chunks ...           Catprolady
# 38555  Nutro Max Adult Chicken Supreme Entree Chunks ...                 Gena
# 38556  Nutro Max Adult Chicken Supreme Entree Chunks ...              Goodcuz
# 38557  Nutro Max Adult Chicken Supreme Entree Chunks ...              Maxwell
# 38558  Nutro Max Adult Chicken Supreme Entree Chunks ...               ck1020
#
#        rating  review_text  helpful_rank        brand   price  oz_per_can  \
# 0           5          NaN             1  Fancy Feast  $14.79         3.0
# 1           5          NaN             2  Fancy Feast  $14.79         3.0
# 2           5          NaN             2  Fancy Feast  $14.79         3.0
# 3           5          NaN             2  Fancy Feast  $14.79         3.0
# 4           5          NaN             0  Fancy Feast  $14.79         3.0
# 5           3          NaN             2  Fancy Feast  $14.79         3.0
# 6           5          NaN             1  Fancy Feast  $14.79         3.0
# 7           5          NaN             1  Fancy Feast  $14.79         3.0
# 8           1          NaN             1  Fancy Feast  $14.79         3.0
# 9           4          NaN             2  Fancy Feast  $14.79         3.0
# 10          5          NaN             0  Fancy Feast  $14.79         3.0
# 11          5          NaN             0  Fancy Feast  $14.79         3.0
# 12          5          NaN             1  Fancy Feast  $14.79         3.0
# 13          5          NaN             0  Fancy Feast  $14.79         3.0
# 14          5          NaN             0  Fancy Feast  $14.79         3.0
# 15          5          NaN             0  Fancy Feast  $14.79         3.0
# 16          5          NaN             2  Fancy Feast  $14.79         3.0
# 17          1          NaN             0  Fancy Feast  $14.79         3.0
# 18          5          NaN             0  Fancy Feast  $14.79         3.0
# 19          5          NaN             0  Fancy Feast  $14.79         3.0
# 20          4          NaN             2  Fancy Feast  $14.79         3.0
# 21          5          NaN             1  Fancy Feast  $14.79         3.0
# 22          2          NaN             0  Fancy Feast  $14.79         3.0
# 23          5          NaN             1  Fancy Feast  $14.79         3.0
# 24          5          NaN             1  Fancy Feast  $14.79         3.0
# 25          5          NaN             0  Fancy Feast  $14.79         3.0
# 26          5          NaN             0  Fancy Feast  $14.79         3.0
# 27          5          NaN             2  Fancy Feast  $14.79         3.0
# 28          5          NaN             0  Fancy Feast  $14.79         3.0
# 29          5          NaN             0  Fancy Feast  $14.79         3.0
# ...       ...          ...           ...          ...     ...         ...
# 38529       5          NaN             2    Nutro Max  $19.20         3.0
# 38530       5          NaN             3    Nutro Max  $19.20         3.0
# 38531       5          NaN             1    Nutro Max  $19.20         3.0
# 38532       5          NaN             1    Nutro Max  $19.20         3.0
# 38533       5          NaN             0    Nutro Max  $19.20         3.0
# 38534       5          NaN             2    Nutro Max  $19.20         3.0
# 38535       5          NaN             2    Nutro Max  $19.20         3.0
# 38536       5          NaN             3    Nutro Max  $19.20         3.0
# 38537       5          NaN             2    Nutro Max  $19.20         3.0
# 38538       5          NaN             1    Nutro Max  $19.20         3.0
# 38539       5          NaN             0    Nutro Max  $19.20         3.0
# 38540       5          NaN             2    Nutro Max  $19.20         3.0
# 38541       5          NaN             0    Nutro Max  $19.20         3.0
# 38542       5          NaN             0    Nutro Max  $19.20         3.0
# 38543       5          NaN             0    Nutro Max  $19.20         3.0
# 38544       4          NaN             1    Nutro Max  $19.20         3.0
# 38545       5          NaN             0    Nutro Max  $19.20         3.0
# 38546       5          NaN             0    Nutro Max  $19.20         3.0
# 38547       5          NaN             2    Nutro Max  $19.20         3.0
# 38548       5          NaN             0    Nutro Max  $19.20         3.0
# 38549       5          NaN             0    Nutro Max  $19.20         3.0
# 38550       3          NaN             4    Nutro Max  $19.20         3.0
# 38551       5          NaN             0    Nutro Max  $19.20         3.0
# 38552       5          NaN             0    Nutro Max  $19.20         3.0
# 38553       5          NaN             0    Nutro Max  $19.20         3.0
# 38554       5          NaN             0    Nutro Max  $19.20         3.0
# 38555       5          NaN             1    Nutro Max  $19.20         3.0
# 38556       5          NaN             0    Nutro Max  $19.20         3.0
# 38557       5          NaN             0    Nutro Max  $19.20         3.0
# 38558       2          NaN             0    Nutro Max  $19.20         3.0
#
#        num_cans  price_per_oz  product_label
# 0          24.0      0.205417            123
# 1          24.0      0.205417            123
# 2          24.0      0.205417            123
# 3          24.0      0.205417            123
# 4          24.0      0.205417            123
# 5          24.0      0.205417            123
# 6          24.0      0.205417            123
# 7          24.0      0.205417            123
# 8          24.0      0.205417            123
# 9          24.0      0.205417            123
# 10         24.0      0.205417            123
# 11         24.0      0.205417            123
# 12         24.0      0.205417            123
# 13         24.0      0.205417            123
# 14         24.0      0.205417            123
# 15         24.0      0.205417            123
# 16         24.0      0.205417            123
# 17         24.0      0.205417            123
# 18         24.0      0.205417            123
# 19         24.0      0.205417            123
# 20         24.0      0.205417            123
# 21         24.0      0.205417            123
# 22         24.0      0.205417            123
# 23         24.0      0.205417            123
# 24         24.0      0.205417            123
# 25         24.0      0.205417            123
# 26         24.0      0.205417            123
# 27         24.0      0.205417            123
# 28         24.0      0.205417            123
# 29         24.0      0.205417            123
# ...         ...           ...            ...
# 38529      24.0      0.266667            319
# 38530      24.0      0.266667            319
# 38531      24.0      0.266667            319
# 38532      24.0      0.266667            319
# 38533      24.0      0.266667            319
# 38534      24.0      0.266667            319
# 38535      24.0      0.266667            319
# 38536      24.0      0.266667            319
# 38537      24.0      0.266667            319
# 38538      24.0      0.266667            319
# 38539      24.0      0.266667            319
# 38540      24.0      0.266667            319
# 38541      24.0      0.266667            319
# 38542      24.0      0.266667            319
# 38543      24.0      0.266667            319
# 38544      24.0      0.266667            319
# 38545      24.0      0.266667            319
# 38546      24.0      0.266667            319
# 38547      24.0      0.266667            319
# 38548      24.0      0.266667            319
# 38549      24.0      0.266667            319
# 38550      24.0      0.266667            319
# 38551      24.0      0.266667            319
# 38552      24.0      0.266667            319
# 38553      24.0      0.266667            319
# 38554      24.0      0.266667            319
# 38555      24.0      0.266667            319
# 38556      24.0      0.266667            319
# 38557      24.0      0.266667            319
# 38558      24.0      0.266667            319
#
# [38351 rows x 11 columns]
